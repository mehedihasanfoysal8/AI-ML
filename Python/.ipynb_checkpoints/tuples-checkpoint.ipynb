# %% [markdown]
# Tuple change করা যায় না ❗

# %%
student = ("Foysal", 20, "Dhaka")

name, age, city = student

print(f"Name: {name}")
print(f"Age: {age}")
print(f"City: {city}")
# Out:
# Name: Foysal
# Age: 20
# City: Dhaka
