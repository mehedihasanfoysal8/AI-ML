# %%
name = "Mehedi Hasan Foysal"
print(name)
# Out:
# Mehedi Hasan Foysal

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name[1]
# Out:
# 'e'

# %%
name = "Hasan"
# this means first value accept kore je kon index theke bad dibe. 
# are last index hocche je kon jaige theke dekhabe.
print(name)

len(name)
# Out:
# Hasan
# 5

# %%
name = "Mehedi Hasan Foysal"

# string manupulation to upper to lower 

print(name.upper())
print(name.lower())
# Out:
# MEHEDI HASAN FOYSAL
# mehedi hasan foysal
