# %%
def create_file(filename, content):
    with open(filename, 'w') as file:
        file.write(content)

create_file("notices.txt", "Hello, this is my first file.")

# %%
import os

if os.path.exists("notes.txt"):
    os.remove("notes.txt")
    print("File deleted")
else:
    print("File not found")
# Out:
# File deleted
