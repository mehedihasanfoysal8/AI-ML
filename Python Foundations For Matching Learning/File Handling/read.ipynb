# %%
file = open("simple.txt", "r")

content = file.read()

print(content)
# Out:
# My name is mehedi hasan foysal
# my father name is siddique
# my mother name is renoja khatun

# %%
file = open("simple.txt", "r")

print(len)

content = file.readline()

print(content)
file.close()
print(file.closed)
# Out:
# 89
#
# True

# %%
with open("simple.txt", "r") as file:
    content = file.read()
    print(content)

print(file.closed)
# Out:
# My name is mehedi hasan foysal
# my father name is siddique
# my mother name is renoja khatun
# True
