# %%
numbers = int(input())
rev_numbers = ''.join(reversed(str(numbers)))

if numbers == int(rev_numbers):
    print ("Mirror Number")
    
else:
  print ("Not Mirror Number")
# Out:
#  717
# Mirror Number
