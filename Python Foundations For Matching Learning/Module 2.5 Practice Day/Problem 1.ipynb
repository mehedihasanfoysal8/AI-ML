# %%
def introduce(name, age):
    print(f'My name is {name} and i am {age} year old.')

introduce("Rahim", 28)
# Out:
# My name is Rahim and i am 28 year old.

# %%
def batch_generator(data, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]

# %%
data = [1, 2, 3, 4, 5, 6, 7, 8]

for batch in batch_generator(data, 3):
    print(batch)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8]

# %%
lst = [1, 2, 3, 4]
result = map(lambda x: x*x, lst) 
print(list(result))
# Out:
# [1, 4, 9, 16]

# %%
def power(b, e = 2):
    return b ** e

power(5, 3)
# Out:
# 125

# %%
lst = [1,2,3,4,5,6]

result = lst.filter(map(lambda x : x % 2 == 0))
